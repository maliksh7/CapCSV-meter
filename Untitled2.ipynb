# %%
import pandas as pd
df = pd.read_hdf('/home/bullbat/fyp-2/Datasets/hdf5/unsignedMNAD.h5')
df
# Out:
#           Destination Port   Flow Duration   Total Fwd Packets  \
# 0                      213               0                   0
# 1                      214               0                   0
# 2                      214               0                   0
# 3                      179               0                   0
# 4                      213               0                   0
# ...                    ...             ...                 ...
# 2830738                  0               0                   0
# 2830739                  0               0                   0
# 2830740                225               0                   0
# 2830741                  0               2                   0
# 2830742                  0               0                   0
#
#           Total Backward Packets  Total Length of Fwd Packets  \
# 0                              0                            0
# 1                              0                            0
# ...

# %%
df = df.rename(columns={' Label': 'label'}, inplace=True)
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_13131/651344052.py in <module>
# ----> 1 df = df.rename(columns={' Label': 'label'}, inplace=True)
#       2 df
#
# AttributeError: 'NoneType' object has no attribute 'rename'

# %%
# df[' Label'].value_counts()
# df[' Label'].count()
# if(df[' Label'] == 'BENIGN'):
#     print("Found Benign Label")
# df[' Label'] == 'PortScan'
# for i in range(2827876):
#     if(df.iloc[i][' Label'] == 'BENIGN'):
#         print("Yes")
#     else:
#         print("No")
# import numpy as np
# np.random.seed(10)
# # cut = 1171320
# ben_label = 11
# for i in range(1,10):
#     dff = df.loc[df[' Label'] == 'BENIGN']
# #     drop_indices = np.random.choice(dff[' Label'], ben_label, replace=False)
#     df_subset = df.drop(dff)
# dff.replace(' Label', 'label')

# %%
# b_label = df[' Label'] == 'BENIGN'
# d_label = df[' Label'] == 'PortScan'
# df.drop_duplicates(subset = [" Label"]

# %%
# df.loc[df[' Label'] == 'BENIGN'].shape[0] - 1171320

# %%
df
# Out:
#           Destination Port   Flow Duration   Total Fwd Packets  \
# 0                      213               0                   0
# 1                      214               0                   0
# 2                      214               0                   0
# 3                      179               0                   0
# 4                      213               0                   0
# ...                    ...             ...                 ...
# 2830738                  0               0                   0
# 2830739                  0               0                   0
# 2830740                225               0                   0
# 2830741                  0               2                   0
# 2830742                  0               0                   0
#
#           Total Backward Packets  Total Length of Fwd Packets  \
# 0                              0                            0
# 1                              0                            0
# ...
